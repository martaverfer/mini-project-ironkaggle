# %%
# Standard libraries
import pandas as pd
import numpy as np
import pickle

# Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.ensemble import RandomForestRegressor

# Enable auto-reload for module reloading during development
# %load_ext autoreload
# %autoreload 2

# Set display options for Pandas to show all columns
pd.set_option('display.max_columns', None)

# Load custom scripts
import scp.data_check as ch
import scp.decision_tree as dt
import scp.random_forest as rf
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load dataset
assets = pd.read_csv('dataset/king_country_houses_aa.csv')

# %%
# Copy of the data
df = assets.copy()

# %%
# Selecting features 
correlated_columns = dt.selecting_features(df, corr_coef=0.25)
# Out:
# Features with correlation coefficient with price > than 0.25
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']

# %%
X_train, X_test, y_train, y_test = dt.select_training_set(df, correlated_columns, test_size=0.4)
# Out:
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646

# %%
results_df, results_list, model_tree = rf.train_random_forest(X_train, X_test, y_train, y_test)
results_df.head()
# Out:
#   Model Metrics: | R2 = 0.7999 | RMSE = 172942.0715 | MAE = 91992.6531 | MSE = 29908960081.1685 |
# ✅ The model performs well! It explains a large portion of the variance.
#        Actual Price  Predicted Price  Difference
# 735        365000.0        387280.50   -22280.50
# 2830       865000.0        812106.34    52893.66
# 4106      1038000.0       1154875.50  -116875.50
# 16218     1490000.0       1610800.00  -120800.00
# 19964      711000.0        785257.38   -74257.38

# %%
# Testing different test sizes
results_list = rf.create_train_test_splits_and_evaluate(df, correlated_columns)
# Out:
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.8091 | RMSE = 166777.0138 | MAE = 90990.0963 | MSE = 27814572347.5594 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7825 | RMSE = 181334.8067 | MAE = 91277.6293 | MSE = 32882312128.0807 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7874 | RMSE = 175184.2849 | MAE = 91380.1656 | MSE = 30689533661.68 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.7999 | RMSE = 172942.0715 | MAE = 91992.6531 | MSE = 29908960081.1685 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 50%:
#   Training set size: 10806 | Test set size: 10807
#   Model Metrics: | R2 = 0.7826 | RMSE = 179948.948 | MAE = 92494.6577 | MSE = 32381623885.9273 |
# ✅ The model performs well! It explains a large portion of the variance.

# %%
# Evaluating different test_size and features
results_df = rf.evaluate_different_correlations(df)
# Out:
# Features with correlation coefficient with price > than 0.2
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.8091 | RMSE = 166777.0138 | MAE = 90990.0963 | MSE = 27814572347.5594 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7825 | RMSE = 181334.8067 | MAE = 91277.6293 | MSE = 32882312128.0807 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7874 | RMSE = 175184.2849 | MAE = 91380.1656 | MSE = 30689533661.68 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.7999 | RMSE = 172942.0715 | MAE = 91992.6531 | MSE = 29908960081.1685 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 50%:
#   Training set size: 10806 | Test set size: 10807
#   Model Metrics: | R2 = 0.7826 | RMSE = 179948.948 | MAE = 92494.6577 | MSE = 32381623885.9273 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# Features with correlation coefficient with price > than 0.25
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.8091 | RMSE = 166777.0138 | MAE = 90990.0963 | MSE = 27814572347.5594 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7825 | RMSE = 181334.8067 | MAE = 91277.6293 | MSE = 32882312128.0807 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7874 | RMSE = 175184.2849 | MAE = 91380.1656 | MSE = 30689533661.68 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.7999 | RMSE = 172942.0715 | MAE = 91992.6531 | MSE = 29908960081.1685 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 50%:
#   Training set size: 10806 | Test set size: 10807
#   Model Metrics: | R2 = 0.7826 | RMSE = 179948.948 | MAE = 92494.6577 | MSE = 32381623885.9273 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# Features with correlation coefficient with price > than 0.3
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.7902 | RMSE = 174807.8404 | MAE = 94323.8456 | MSE = 30557781072.3411 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7552 | RMSE = 192361.5075 | MAE = 94417.8168 | MSE = 37002949559.7446 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7688 | RMSE = 182714.3911 | MAE = 94511.065 | MSE = 33384548699.9883 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.7826 | RMSE = 180265.3401 | MAE = 94269.3217 | MSE = 32495592838.2513 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 50%:
#   Training set size: 10806 | Test set size: 10807
#   Model Metrics: | R2 = 0.7768 | RMSE = 182320.7929 | MAE = 94869.4694 | MSE = 33240871522.3004 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# Features with correlation coefficient with price > than 0.35
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.6027 | RMSE = 240580.9469 | MAE = 152784.2846 | MSE = 57879192005.0062 |
# ⚠️ The model is moderately good, but there’s room for improvement.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.5746 | RMSE = 253608.9882 | MAE = 154351.79 | MSE = 64317518899.7544 |
# ⚠️ The model is moderately good, but there’s room for improvement.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.5931 | RMSE = 242362.0111 | MAE = 153478.3559 | MSE = 58739344437.2792 |
# ⚠️ The model is moderately good, but there’s room for improvement.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.6293 | RMSE = 235403.6605 | MAE = 150322.2815 | MSE = 55414883368.2148 |
# ⚠️ The model is moderately good, but there’s room for improvement.
#
# 🔹 Test size 50%:
#   Training set size: 10806 | Test set size: 10807
#   Model Metrics: | R2 = 0.6275 | RMSE = 235564.8884 | MAE = 149861.5228 | MSE = 55490816666.1988 |
# ⚠️ The model is moderately good, but there’s room for improvement.
#
# Features with correlation coefficient with price > than 0.4
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.5739 | RMSE = 249144.5269 | MAE = 155642.8262 | MSE = 62072995272.9294 |
# ⚠️ The model is moderately good, but there’s room for improvement.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.

#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.4982 | RMSE = 273894.2552 | MAE = 173572.404 | MSE = 75018063056.5659 |
# ❌ The model performs poorly. Consider tuning hyperparameters or using a different approach.
#
# 🔹 Test size 50%:
#   Training set size: 10806 | Test set size: 10807
#   Model Metrics: | R2 = 0.4971 | RMSE = 273697.6272 | MAE = 174503.739 | MSE = 74910391162.1234 |
# ❌ The model performs poorly. Consider tuning hyperparameters or using a different approach.
#
# Features with correlation coefficient with price > than 0.75
# ⚠️ No features meet this correlation threshold. Ending...

# %%
# A resume of metrics for test_size and features
results_df.head(55)
# Out:
#     Correlation Coefficient ≥  Test Size (%)        R²           RMSE  \
# 0                        0.20            0.1  0.809070  166777.013847
# 1                        0.20            0.2  0.782491  181334.806720
# 2                        0.20            0.3  0.787419  175184.284859
# 3                        0.20            0.4  0.799920  172942.071461
# 4                        0.20            0.5  0.782604  179948.947999
# 5                        0.25            0.1  0.809070  166777.013847
# 6                        0.25            0.2  0.782491  181334.806720
# 7                        0.25            0.3  0.787419  175184.284859
# 8                        0.25            0.4  0.799920  172942.071461
# 9                        0.25            0.5  0.782604  179948.947999
# 10                       0.30            0.1  0.790239  174807.840420
# 11                       0.30            0.2  0.755234  192361.507479
# 12                       0.30            0.3  0.768751  182714.391059
# 13                       0.30            0.4  0.782617  180265.340091
# 14                       0.30            0.5  0.776835  182320.792896
# 15                       0.35            0.1  0.602694  240580.946887
# 16                       0.35            0.2  0.574554  253608.988208
# 17                       0.35            0.3  0.593124  242362.011126
# 18                       0.35            0.4  0.629295  235403.660482
# 19                       0.35            0.5  0.627459  235564.888441
# 20                       0.40            0.1  0.573906  249144.526877
# 21                       0.40            0.2  0.543288  262762.787284
# 22                       0.40            0.3  0.555740  253251.538798
# 23                       0.40            0.4  0.598147  245094.188509
# 24                       0.40            0.5  0.596224  245241.465265
# 25                       0.45            0.1  0.573906  249144.526877
# 26                       0.45            0.2  0.543288  262762.787284
# 27                       0.45            0.3  0.555740  253251.538798
# 28                       0.45            0.4  0.598147  245094.188509
# 29                       0.45            0.5  0.596224  245241.465265
# 30                       0.50            0.1  0.573906  249144.526877
# 31                       0.50            0.2  0.543288  262762.787284
# 32                       0.50            0.3  0.555740  253251.538798
# 33                       0.50            0.4  0.598147  245094.188509
# 34                       0.50            0.5  0.596224  245241.465265
# 35                       0.55            0.1  0.565170  251685.683149
# 36                       0.55            0.2  0.550350  260723.333231
# 37                       0.55            0.3  0.550554  254725.278583
# 38                       0.55            0.4  0.589881  247602.146681
# 39                       0.55            0.5  0.585023  248619.762200
# 40                       0.60            0.1  0.553707  254981.441739
# 41                       0.60            0.2  0.539084  263969.208470
# 42                       0.60            0.3  0.543544  256704.088210
# 43                       0.60            0.4  0.570444  253401.519077
# 44                       0.60            0.5  0.556126  257130.310899
# 45                       0.65            0.1  0.532269  261033.635856
# 46                       0.65            0.2  0.509247  272379.168329
# 47                       0.65            0.3  0.505446  267202.232706
# 48                       0.65            0.4  0.532382  264389.866717
# 49                       0.65            0.5  0.526312  265625.592033
# 50                       0.70            0.1  0.489471  272714.969018
# 51                       0.70            0.2  0.457292  286434.667023
# 52                       0.70            0.3  0.466226  277595.254961
# 53                       0.70            0.4  0.498158  273894.255246
# 54                       0.70            0.5  0.497084  273697.627250
#
#               MAE           MSE
# 0    90990.096250  2.781457e+10
# 1    91277.629334  3.288231e+10
# 2    91380.165613  3.068953e+10
# 3    91992.653123  2.990896e+10
# 4    92494.657674  3.238162e+10
# 5    90990.096250  2.781457e+10
# 6    91277.629334  3.288231e+10
# 7    91380.165613  3.068953e+10
# 8    91992.653123  2.990896e+10
# 9    92494.657674  3.238162e+10
# 10   94323.845633  3.055778e+10
# 11   94417.816817  3.700295e+10
# 12   94511.064985  3.338455e+10
# 13   94269.321651  3.249559e+10
# 14   94869.469373  3.324087e+10
# 15  152784.284629  5.787919e+10
# 16  154351.789963  6.431752e+10
# 17  153478.355887  5.873934e+10
# 18  150322.281530  5.541488e+10
# 19  149861.522811  5.549082e+10
# 20  155642.826248  6.207300e+10
# 21  157931.818126  6.904428e+10
# 22  157614.382760  6.413634e+10
# 23  154325.093977  6.007116e+10
# 24  154461.795608  6.014338e+10
# 25  155642.826248  6.207300e+10
# 26  157931.818126  6.904428e+10
# 27  157614.382760  6.413634e+10
# 28  154325.093977  6.007116e+10
# 29  154461.795608  6.014338e+10
# 30  155642.826248  6.207300e+10
# 31  157931.818126  6.904428e+10
# 32  157614.382760  6.413634e+10
# 33  154325.093977  6.007116e+10
# 34  154461.795608  6.014338e+10
# 35  159763.719660  6.334568e+10
# 36  161001.122877  6.797666e+10
# 37  160551.715019  6.488497e+10
# 38  158250.138042  6.130682e+10
# 39  158067.387929  6.181179e+10
# 40  162646.862689  6.501554e+10
# 41  162926.796536  6.967974e+10
# 42  162680.851246  6.589699e+10
# 43  162206.991291  6.421233e+10
# 44  163659.447963  6.611600e+10
# 45  164707.559640  6.813856e+10
# 46  166001.539762  7.419041e+10
# 47  166835.694966  7.139703e+10
# 48  167042.247974  6.990200e+10
# 49  168215.288480  7.055696e+10
# 50  174851.503535  7.437345e+10
# 51  175793.816420  8.204482e+10
# 52  174662.967354  7.705913e+10
# 53  173572.403972  7.501806e+10
# 54  174503.739041  7.491039e+10

# %%
# Evaluating different test_size, features and number of trees
results_df = rf.evaluate_different_estimators(df)
# Out:
# Number of tree: 10
# Features with correlation coefficient with price > than 0.2
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.7895 | RMSE = 175130.2935 | MAE = 95982.9073 | MSE = 30670619702.8329 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7727 | RMSE = 185353.7701 | MAE = 94299.4301 | MSE = 34356020092.1631 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7691 | RMSE = 182586.0928 | MAE = 96040.4825 | MSE = 33337681300.228 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.7772 | RMSE = 182499.7969 | MAE = 96179.1193 | MSE = 33306175873.672 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# Features with correlation coefficient with price > than 0.25
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.7895 | RMSE = 175130.2935 | MAE = 95982.9073 | MSE = 30670619702.8329 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7727 | RMSE = 185353.7701 | MAE = 94299.4301 | MSE = 34356020092.1631 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7691 | RMSE = 182586.0928 | MAE = 96040.4825 | MSE = 33337681300.228 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.7772 | RMSE = 182499.7969 | MAE = 96179.1193 | MSE = 33306175873.672 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# Number of tree: 50
# Features with correlation coefficient with price > than 0.2
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.801 | RMSE = 170250.9718 | MAE = 92085.7744 | MSE = 28985393411.2469 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7831 | RMSE = 181090.7396 | MAE = 91155.1548 | MSE = 32793855986.1806 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7866 | RMSE = 175534.0605 | MAE = 91789.0541 | MSE = 30812206394.9901 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.797 | RMSE = 174181.2031 | MAE = 92338.6653 | MSE = 30339091526.1338 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# Features with correlation coefficient with price > than 0.25
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.801 | RMSE = 170250.9718 | MAE = 92085.7744 | MSE = 28985393411.2469 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7831 | RMSE = 181090.7396 | MAE = 91155.1548 | MSE = 32793855986.1806 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.
|
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.8004 | RMSE = 172747.3644 | MAE = 91716.2301 | MSE = 29841651905.2813 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# Features with correlation coefficient with price > than 0.25
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 10%:
#   Training set size: 19451 | Test set size: 2162
#   Model Metrics: | R2 = 0.8095 | RMSE = 166590.5178 | MAE = 90614.6604 | MSE = 27752400605.7714 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#   Model Metrics: | R2 = 0.7842 | RMSE = 180636.7734 | MAE = 91257.1358 | MSE = 32629643922.2552 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#   Model Metrics: | R2 = 0.7895 | RMSE = 174316.1198 | MAE = 91280.6756 | MSE = 30386109607.7525 |
# ✅ The model performs well! It explains a large portion of the variance.
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.8004 | RMSE = 172747.3644 | MAE = 91716.2301 | MSE = 29841651905.2813 |
# ✅ The model performs well! It explains a large portion of the variance.

# %%
# A resume of metrics for test_size, features ans estimators
results_df.head(55)
# Out:
#     Estimator  Correlation Coefficient ≥  Test Size (%)        R²  \
# 0          10                       0.20            0.1  0.789464
# 1          10                       0.20            0.2  0.772743
# 2          10                       0.20            0.3  0.769076
# 3          10                       0.20            0.4  0.777194
# 4          10                       0.25            0.1  0.789464
# 5          10                       0.25            0.2  0.772743
# 6          10                       0.25            0.3  0.769076
# 7          10                       0.25            0.4  0.777194
# 8          50                       0.20            0.1  0.801033
# 9          50                       0.20            0.2  0.783076
# 10         50                       0.20            0.3  0.786570
# 11         50                       0.20            0.4  0.797043
# 12         50                       0.25            0.1  0.801033
# 13         50                       0.25            0.2  0.783076
# 14         50                       0.25            0.3  0.786570
# 15         50                       0.25            0.4  0.797043
# 16        100                       0.20            0.1  0.809070
# 17        100                       0.20            0.2  0.782491
# 18        100                       0.20            0.3  0.787419
# 19        100                       0.20            0.4  0.799920
# 20        100                       0.25            0.1  0.809070
# 21        100                       0.25            0.2  0.782491
# 22        100                       0.25            0.3  0.787419
# 23        100                       0.25            0.4  0.799920
# 24        200                       0.20            0.1  0.809821
# 25        200                       0.20            0.2  0.785743
# 26        200                       0.20            0.3  0.789485
# 27        200                       0.20            0.4  0.800136
# 28        200                       0.25            0.1  0.809821
# 29        200                       0.25            0.2  0.785743
# 30        200                       0.25            0.3  0.789485
# 31        200                       0.25            0.4  0.800136
# 32        300                       0.20            0.1  0.808876
# 33        300                       0.20            0.2  0.784488
# 34        300                       0.20            0.3  0.791433
# 35        300                       0.20            0.4  0.799409
# 36        300                       0.25            0.1  0.808876
# 37        300                       0.25            0.2  0.784488
# 38        300                       0.25            0.3  0.791433
# 39        300                       0.25            0.4  0.799409
# 40        500                       0.20            0.1  0.808948
# 41        500                       0.20            0.2  0.785994
# 42        500                       0.20            0.3  0.790951
# 43        500                       0.20            0.4  0.799273
# 44        500                       0.25            0.1  0.808948
# 45        500                       0.25            0.2  0.785994
# 46        500                       0.25            0.3  0.790951
# 47        500                       0.25            0.4  0.799273
# 48       1000                       0.20            0.1  0.809496
# 49       1000                       0.20            0.2  0.784162
# 50       1000                       0.20            0.3  0.789521
# 51       1000                       0.20            0.4  0.800371
# 52       1000                       0.25            0.1  0.809496
# 53       1000                       0.25            0.2  0.784162
# 54       1000                       0.25            0.3  0.789521
#
#              RMSE           MAE           MSE
# 0   175130.293504  95982.907343  3.067062e+10
# 1   185353.770105  94299.430123  3.435602e+10
# 2   182586.092845  96040.482474  3.333768e+10
# 3   182499.796914  96179.119325  3.330618e+10
# 4   175130.293504  95982.907343  3.067062e+10
# 5   185353.770105  94299.430123  3.435602e+10
# 6   182586.092845  96040.482474  3.333768e+10
# 7   182499.796914  96179.119325  3.330618e+10
# 8   170250.971836  92085.774405  2.898539e+10
# 9   181090.739648  91155.154795  3.279386e+10
# 10  175534.060498  91789.054111  3.081221e+10
# 11  174181.203137  92338.665302  3.033909e+10
# 12  170250.971836  92085.774405  2.898539e+10
# 13  181090.739648  91155.154795  3.279386e+10
# 14  175534.060498  91789.054111  3.081221e+10
# 15  174181.203137  92338.665302  3.033909e+10
# 16  166777.013847  90990.096250  2.781457e+10
# 17  181334.806720  91277.629334  3.288231e+10
# 18  175184.284859  91380.165613  3.068953e+10
# 19  172942.071461  91992.653123  2.990896e+10
# 20  166777.013847  90990.096250  2.781457e+10
# 21  181334.806720  91277.629334  3.288231e+10
# 22  175184.284859  91380.165613  3.068953e+10
# 23  172942.071461  91992.653123  2.990896e+10
# 24  166448.640187  90655.441537  2.770515e+10
# 25  179974.234613  91352.531107  3.239073e+10
# 26  174331.210483  91116.729074  3.039137e+10
# 27  172849.000406  91907.793105  2.987678e+10
# 28  166448.640187  90655.441537  2.770515e+10
# 29  179974.234613  91352.531107  3.239073e+10
# 30  174331.210483  91116.729074  3.039137e+10
# 31  172849.000406  91907.793105  2.987678e+10
# 32  166861.486136  90716.164410  2.784276e+10
# 33  180500.312957  91272.348368  3.258036e+10
# 34  173522.656224  90989.186984  3.011011e+10
# 35  173162.781906  91881.200989  2.998535e+10
# 36  166861.486136  90716.164410  2.784276e+10
# 37  180500.312957  91272.348368  3.258036e+10
# 38  173522.656224  90989.186984  3.011011e+10
# 39  173162.781906  91881.200989  2.998535e+10
# 40  166830.269453  90635.003322  2.783234e+10
# 41  179868.784251  91119.828262  3.235278e+10
# 42  173723.083747  91072.994097  3.017971e+10
# 43  173221.450502  91814.631544  3.000567e+10
# 44  166830.269453  90635.003322  2.783234e+10
# 45  179868.784251  91119.828262  3.235278e+10
# 46  173723.083747  91072.994097  3.017971e+10
# 47  173221.450502  91814.631544  3.000567e+10
# 48  166590.517755  90614.660353  2.775240e+10
# 49  180636.773450  91257.135762  3.262964e+10
# 50  174316.119759  91280.675617  3.038611e+10
# 51  172747.364395  91716.230116  2.984165e+10
# 52  166590.517755  90614.660353  2.775240e+10
# 53  180636.773450  91257.135762  3.262964e+10
# 54  174316.119759  91280.675617  3.038611e+10

# %%
# Cross validation
results, average = rf.cross_validate_model(df, correlated_columns)
results
# Out:
# Cross-Validation Results:
# Number of folds: 5
# Average Training R²:  0.9721
# Average Test R²:  0.81
# ✅ The model performs well on unseen data, explaining a large portion of the variance.
#    Fold  Train R²  Test R²
# 0     1    0.9723   0.7730
# 1     2    0.9715   0.8094
# 2     3    0.9719   0.8160
# 3     4    0.9725   0.8351
# 4     5    0.9723   0.8165

# %%
#results_df = rf.perform_grid_search(df)
# Out:
# ==================================================
# Features with correlation coefficient with price > than 0.25
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# ==================================================
# 🔹 Test size 20%:
#   Training set size: 17290 | Test set size: 4323
#
#   Number of folds 5
#
# ✅ Best R² Score: 0.8177
# 🏆 Best Parameters: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
#
# ✅ Excellent model! The fit is strong.
# 🔹 Test size 30%:
#   Training set size: 15129 | Test set size: 6484
#
#   Number of folds 5
#
# ✅ Best R² Score: 0.8171
# 🏆 Best Parameters: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
#
# ✅ Excellent model! The fit is strong.
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#
#   Number of folds 5
#
# ✅ Best R² Score: 0.8041
# 🏆 Best Parameters: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
#
# ✅ Excellent model! The fit is strong.

# %%
best_parameters = {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
best_correlation = 0.25
best_test_size = 0.4
final_model = RandomForestRegressor(**best_parameters, random_state=42)

correlated_columns = dt.selecting_features(df, corr_coef=best_correlation)
X_train, X_test, y_train, y_test = dt.select_training_set(df, correlated_columns, test_size=best_test_size)
results_df, results_list, final_model = rf.train_random_forest(X_train, X_test, y_train, y_test, model_tree=final_model)
# Out:
# Features with correlation coefficient with price > than 0.25
# Columns that will be used for the training:
#  ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors']
#
# 🔹 Test size 40%:
#   Training set size: 12967 | Test set size: 8646
#   Model Metrics: | R2 = 0.8004 | RMSE = 172748.9559 | MAE = 91815.6874 | MSE = 29842201769.608 |
# ✅ The model performs well! It explains a large portion of the variance.

# %%
results, average = dt.cross_validate_model(df, correlated_columns, model_tree=final_model)
results
# Out:
# Cross-Validation Results:
# Number of folds: 5
# Average Training R²:  0.9711
# Average Test R²:  0.8145
# ✅ The model performs well on unseen data, explaining a large portion of the variance.
#    Fold  Train R²  Test R²
# 0     1    0.9713   0.7808
# 1     2    0.9712   0.8140
# 2     3    0.9713   0.8226
# 3     4    0.9704   0.8351
# 4     5    0.9714   0.8202

# %%
# Get feature importance scores
importance_df = dt.feature_score(final_model, X_train)
importance_df
# Out:
#           Feature  Importance
# 0     sqft_living    0.329792
# 1           grade    0.283321
# 8             lat    0.197671
# 3   sqft_living15    0.044920
# 5            view    0.032196
# 9      waterfront    0.032039
# 2      sqft_above    0.026499
# 4       bathrooms    0.020096
# 6   sqft_basement    0.016390
# 7        bedrooms    0.009050
# 10         floors    0.008025

# %%
# Initialize RFE and select the top 5 features
correlated_columns, results_df, final_model = dt.feature_selection(final_model, X_train, X_test, y_train, y_test, features=11)
# Out:
# Selected Features: Index(['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms',
#        'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors'],
#       dtype='object')
#   Model Metrics: | R2 = 0.8004 | RMSE = 172748.9559 | MAE = 91815.6874 | MSE = 29842201769.608 |
# ✅ The model performs well! It explains a large portion of the variance.

# %%
results_df.head(5)
# Out:
#        Actual Price  Predicted Price     Difference
# 735        365000.0     3.957498e+05  -30749.806818
# 2830       865000.0     8.399796e+05   25020.352980
# 4106      1038000.0     1.177641e+06 -139640.758814
# 16218     1490000.0     1.596872e+06 -106872.315000
# 19964      711000.0     7.727767e+05  -61776.727577

# %%
results, average = dt.cross_validate_model(df, correlated_columns, model_tree=final_model)
results
# Out:
# Cross-Validation Results:
# Number of folds: 5
# Average Training R²:  0.9711
# Average Test R²:  0.8145
# ✅ The model performs well on unseen data, explaining a large portion of the variance.
#    Fold  Train R²  Test R²
# 0     1    0.9713   0.7808
# 1     2    0.9712   0.8140
# 2     3    0.9713   0.8226
# 3     4    0.9704   0.8351
# 4     5    0.9714   0.8202

# %%
# Save the model
with open('house_price_random_forest_regression.pkl', 'wb') as f:
    pickle.dump(final_model, f)

# %%
dt.model_validation(results_df, final_model, X_train, X_test, y_train, y_test)
